# %%
print("hello world")
# Out:
# hello world

# %%
from lib import print1
print1("HELLO WORLD")

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 print1("HELLO")
#
# NameError: name 'print1' is not defined
